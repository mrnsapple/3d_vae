# %%
# Program to concatenate two 2D arrays row-wise
import numpy as np
import pandas as pd
# Creating two 2D arrays
arr1 = np.empty((600, 3))
name1 = "gaga"
init_df = pd.DataFrame()
dataframe1 = pd.DataFrame(arr1, columns = ["X", "Y", "Z"])
dataframe1["obj_name"] = name1
arr1 = np.empty((300, 3))
name2 = "ff"
dataframe2 = pd.DataFrame(arr1, columns = ["X", "Y", "Z"])
pd.concat([dataframe1, dataframe2])
# Out:
#                  X              Y              Z obj_name
# 0    6.924766e-310  6.924766e-310  3.472076e-316     gaga
# 1    3.472076e-316  6.924497e-310  3.472162e-316     gaga
# 2    6.924709e-310  3.476204e-316  6.924709e-310     gaga
# 3    3.472162e-316  6.924709e-310  3.472078e-316     gaga
# 4    6.924497e-310  3.472094e-316  6.924709e-310     gaga
# ..             ...            ...            ...      ...
# 295  6.924708e-310  6.924708e-310  6.924708e-310      NaN
# 296  6.924708e-310  6.924708e-310  6.924708e-310      NaN
# 297  6.924708e-310  6.924708e-310  6.924708e-310      NaN
# 298  6.924708e-310  6.924708e-310  6.924708e-310      NaN
# 299  6.924708e-310  6.924708e-310  6.924708e-310      NaN
#
# [900 rows x 4 columns]

# %%
import numpy as np

a = np.empty((10,2, 2))
percentage = 0.4
print(a.shape)
b = a[:int(a.shape[0]*percentage)]
print(b.shape)
print(a.shape)

c = a[int(a.shape[0]*(1-percentage)):]
print(c.shape)
# Out:
# (10, 2, 2)
# (4, 2, 2)
# (10, 2, 2)
# (3, 2, 2)
